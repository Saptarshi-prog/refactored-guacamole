# %% [markdown]
# <a href="https://colab.research.google.com/github/Saptarshi-prog/refactored-guacamole/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tp
import numpy as np
from tensorflow import keras

model=keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

model.compile(optimizer='sgd', loss='mean_squared_error')

xs= np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys= np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs,ys, epochs=500)
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 39.6435
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 31.5431
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 25.1628
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 20.1360
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 16.1741
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 13.0504
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.5860
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6407
# Epoch 9/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1037
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 5.8883
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9259
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1627
# ...
